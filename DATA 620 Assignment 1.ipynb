# %%
import networkx as nx

# %%
kite=nx.Graph()

# %%
nlist=[("Ed","Andre"),("Becca","Andre"),("Diane","Andre"),("Ed","Carol"),("Ed","Diane"),("Carol","Diane"),("Carol","Garth"),("Garth","Diane"),("Garth","Fred"),("Garth","Harry"),("Harry","Becca"),("Harry","Diane"),("Harry","Fred"),("Fred","Ivan"),("Ivan","Jan"),("Becca","Diane")]

# %%
kite.add_edges_from(nlist)

# %%
nx.draw(kite,with_labels=True,font_weight="bold")
